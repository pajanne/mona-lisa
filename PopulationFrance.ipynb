# %%
pop = {'1900': 885,
       '1910': 828,
       '1920': 838,
       '1930': 754,
       '1940': 561,
       '1950': 862,
       '1960': 820,
       '1970': 850,
       '1980': 800,
       '1990': 762,
       '2000': 775,
       '2009': 821}
# Out:
# {'1900': 885, '1910': 828, '1920': 838, '1930': 754, '1940': 561, '1950': 862, '1960': 820, '1970': 850, '1980': 800, '1990': 762, '2000': 775, '2009': 821}

# %%
import matplotlib.pyplot as mpyplot
mpyplot.plot(list(pop.keys()), list(pop.values()), 'ro')
mpyplot.title('La population de la France')
mpyplot.xlabel('année')
mpyplot.ylabel('nombre de naissance (en milliers)')
mpyplot.show()

# %%
import matplotlib.pyplot as mpyplot
mpyplot.bar(range(len(pop)), list(pop.values()))
mpyplot.show()
